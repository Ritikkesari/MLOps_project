# %%
# app.py

from fastapi import FastAPI, HTTPException, Request
from pydantic import BaseModel, Field
import mlflow
import pandas as pd
import uvicorn
import logging

app = FastAPI()

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Define your MLflow model name and version
model_name = "House-pricing-model"
model_version = "1"

# SQLite URI for MLflow tracking server
mlflow_uri = "sqlite:///mlflow.db"  # Replace with the actual path to your mlflow.db file

try:
    # Initialize MLflow client
    mlflow.set_tracking_uri(mlflow_uri)
    client = mlflow.tracking.MlflowClient()

    # Get registered model details
    model_details = client.get_registered_model(model_name)

    # Load the model using its latest version
    model_version_details = client.get_model_version(model_details.name, model_version)
    model_uri = model_version_details.source

    # Alternatively, you can load the model using specific version URI
    # model_uri = f"{mlflow_uri}#models:/{model_name}/{model_version}"

    # Load the model
    loaded_model = mlflow.pyfunc.load_model(model_uri)
    logger.info(f"Successfully loaded MLflow model '{model_name}' version '{model_version}' from '{model_uri}'")
except Exception as e:
    logger.error(f"Failed to load MLflow model: {str(e)}")
    raise e

# Define input schema using Pydantic BaseModel
class HousePriceInput(BaseModel):
    area: float = Field(..., example=1500)
    bedrooms: int = Field(..., example=3)
    bathrooms: int = Field(..., example=2)
    stories: int = Field(..., example=2)
    parking: int = Field(..., example=1)
    furnished: int = Field(..., example=0)
    semi_furnished: int = Field(..., example=1)
    unfurnished: int = Field(..., example=0)
    mainroad_new: int = Field(..., example=1)

# Define output schema using Pydantic BaseModel
class HousePriceOutput(BaseModel):
    predicted_price: float

# Endpoint to predict house price
@app.post("/predict", response_model=HousePriceOutput)
async def predict_house_price(input_data: HousePriceInput):
    # Convert input data to DataFrame
    input_df = pd.DataFrame([input_data.dict()])

    try:
        # Perform prediction using the loaded model
        prediction = loaded_model.predict(input_df)
        return {"predicted_price": prediction[0]}  # Assuming a single prediction output
    except Exception as e:
        logger.error(f"Prediction error: {str(e)}")
        raise HTTPException(status_code=500, detail="Failed to make predictions")

# Middleware to add process time header
@app.middleware("http")
async def add_process_time_header(request: Request, call_next):
    import time
    start_time = time.time()
    response = await call_next(request)
    process_time = time.time() - start_time
    response.headers["X-Process-Time"] = str(process_time)
    return response

# If running this script directly, start the FastAPI application using uvicorn
if __name__ == "__main__":
    uvicorn.run(app, host="0.0.0.0", port=8000)
# Out:
# ERROR:__main__:Failed to load MLflow model: Registered Model with name=House-pricing-model not found
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[2], line 43
#      41 except Exception as e:
#      42     logger.error(f"Failed to load MLflow model: {str(e)}")
# ---> 43     raise e
#      45 # Define input schema using Pydantic BaseModel
#      46 class HousePriceInput(BaseModel):
#
# Cell In[2], line 29
#      26 client = mlflow.tracking.MlflowClient()
#      28 # Get registered model details
# ---> 29 model_details = client.get_registered_model(model_name)
#      31 # Load the model using its latest version
#      32 model_version_details = client.get_model_version(model_details.name, model_version)
#
# File /opt/conda/envs/venv/lib/python3.12/site-packages/mlflow/tracking/client.py:3394, in MlflowClient.get_registered_model(self, name)
#    3353 def get_registered_model(self, name: str) -> RegisteredModel:
#    3354     """Get a registered model.
#    3355
#    3356     Args:
#    (...)
#    3392         description: This sentiment analysis model classifies the tone-happy, sad, angry.
#    3393     """
# -> 3394     return self._get_registry_client().get_registered_model(name)
#
# File /opt/conda/envs/venv/lib/python3.12/site-packages/mlflow/tracking/_model_registry/client.py:137, in ModelRegistryClient.get_registered_model(self, name)
#     129 def get_registered_model(self, name):
#     130     """
#     131     Args:
#     132         name: Name of the registered model to get.
#    (...)
#     135         A single :py:class:`mlflow.entities.model_registry.RegisteredModel` object.
#     136     """
# --> 137     return self.store.get_registered_model(name)
#
# File /opt/conda/envs/venv/lib/python3.12/site-packages/mlflow/store/model_registry/sqlalchemy_store.py:549, in SqlAlchemyStore.get_registered_model(self, name)
#     539 """
#     540 Get registered model instance by name.
#     541
#    (...)
#     546     A single :py:class:`mlflow.entities.model_registry.RegisteredModel` object.
#     547 """
#     548 with self.ManagedSessionMaker() as session:
# --> 549     return self._get_registered_model(session, name, eager=True).to_mlflow_entity()
#
# File /opt/conda/envs/venv/lib/python3.12/site-packages/mlflow/store/model_registry/sqlalchemy_store.py:213, in SqlAlchemyStore._get_registered_model(cls, session, name, eager)
#     205 rms = (
#     206     session.query(SqlRegisteredModel)
#     207     .options(*query_options)
#     208     .filter(SqlRegisteredModel.name == name)
#     209     .all()
#     210 )
#     212 if len(rms) == 0:
# --> 213     raise MlflowException(
#     214         f"Registered Model with name={name} not found", RESOURCE_DOES_NOT_EXIST
#     215     )
#     216 if len(rms) > 1:
#     217     raise MlflowException(
#     218         f"Expected only 1 registered model with name={name}. Found {len(rms)}.",
#     219         INVALID_STATE,
#     220     )
#
# MlflowException: Registered Model with name=House-pricing-model not found
